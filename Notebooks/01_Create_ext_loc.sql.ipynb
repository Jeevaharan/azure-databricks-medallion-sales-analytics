# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS bronze_loc
URL "abfss://{bronze_container}@{storage_account}.dfs.core.windows.net/"
WITH (STORAGE CREDENTIAL storagecred);

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS silver_loc
URL "abfss://{silver_container}@{storage_account}.dfs.core.windows.net/"
WITH (STORAGE CREDENTIAL storagecred);

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS gold_loc
URL "abfss://{gold_container}@{storage_account}.dfs.core.windows.net/"
WITH (STORAGE CREDENTIAL storagecred);
